# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Magnus Rolandsson**
# Management consultant

# %% [markdown]
# *I'm interested in Data Science as I want to work more hands-on with data in my regular job.*
# *I want to combine my management and business skills with data competence and move towards a more technical role*

# %% [markdown]
# ### The code below will print the classic "hello world" message

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# **This is a bulleted list:**
# * 1
# * 2
# * 3
#
# **This is a numbered list:**
# 1. One
# 2. Two
# 3. Three

# %%
Using Markdown or HTML, this cell must include at least 3 of the following: 
horizontal rule, 
bulleted list, numbered list, tables, hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough.
# Out:
#   File "/tmp/ipykernel_777/3094229698.py", line 1
#     Using Markdown or HTML, this cell must include at least 3 of the following: horizontal rule, bulleted list, numbered list, tables, hyperlinks, images, code/syntax highlighting, blocked quotes, strikethrough.
#                  ^
# SyntaxError: invalid syntax
